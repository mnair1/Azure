# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read Data using CSV library in Python

# %%
data_path = 'trail_Ontario.csv'
with open(data_path, 'r') as f:
    reader = csv.reader(f, delimiter=',')
    # get header from first row
    headers = next(reader)
    # get all the rows as a list
    data = list(reader)
    # transform data into numpy array
    data = np.array(data).astype(float)
    
print(headers)
print(data.shape)
print(data[:3])
# Out:
# ['Latitude', 'Longitude', 'Elevation']
# (1964, 3)
# [[ 45.433445 -75.724642  49.      ]
#  [ 45.432407 -75.724453  52.      ]
#  [ 45.43265  -75.728013  50.      ]]

# %%
# Plot the data
plt.plot(data[:, 1], data[:, 0])
plt.axis('equal')
plt.xlabel(headers[1])
plt.ylabel(headers[0])
plt.show()

plt.plot(data[:, 2])
plt.xlabel('Table Index')
plt.ylabel(headers[2])
plt.show()

# %%
# Read Data using numpy library in Python

# %%
types = ['f8', 'f8', 'i4']
# i4 - 32-bit signed integer
# f8 - 64-bit floating-point number
data = np.genfromtxt(data_path, dtype=types, delimiter=',',names=True)

# %%
print(data)
# Out:
# [(45.433445, -75.724642,  49) (45.432407, -75.724453,  52)
#  (45.43265 , -75.728013,  50) ... (49.881465, -97.127013, 228)
#  (49.884085, -97.131518, 229) (49.890107, -97.134837, 233)]

# %%
plt.plot(data['Longitude'], data['Latitude'])
plt.axis('equal')
plt.show()
plt.show()

# %%
# Read Data using Pandas library in Python

# %%
df = pd.read_csv(data_path)
df.head()
# Out:
#     Latitude  Longitude  Elevation
# 0  45.433445 -75.724642       49.0
# 1  45.432407 -75.724453       52.0
# 2  45.432650 -75.728013       50.0
# 3  45.438867 -75.726042       49.0
# 4  45.450695 -75.716122       47.0

# %%
plt.plot(data['Longitude'], data['Latitude'])
plt.axis('equal')
plt.show()
plt.show()

# %%
df.max()
# Out:
# Latitude      49.890107
# Longitude    -75.512935
# Elevation    503.000000
# dtype: float64

# %%
df['Elevation'].max()
# Out:
# 503.0

# %%
df[df.Elevation == 503.0]
# Out:
#        Latitude  Longitude  Elevation
# 1556  48.685185 -90.827462      503.0

# %%
df[df.Elevation == df['Elevation'].max()]
# Out:
#        Latitude  Longitude  Elevation
# 1556  48.685185 -90.827462      503.0
